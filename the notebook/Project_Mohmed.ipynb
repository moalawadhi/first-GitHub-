# %%
import pandas as pd

# %%
wq=pd.read_csv('1_gecco2018_water_quality.csv')

# %%
wq
# Out:
#         Unnamed: 0                 Time    Tp    Cl    pH  Redox   Leit  \
# 0                1  2016-08-03 11:49:00   6.5  0.17  8.36  749.0  211.0
# 1                2  2016-08-03 11:50:00   6.5  0.17  8.36  749.0  211.0
# 2                3  2016-08-03 11:51:00   6.5  0.17  8.35  749.0  211.0
# 3                4  2016-08-03 11:52:00   6.5  0.17  8.35  749.0  211.0
# 4                5  2016-08-03 11:53:00   6.5  0.17  8.35  749.0  211.0
# ...            ...                  ...   ...   ...   ...    ...    ...
# 139561      139562  2016-11-08 08:50:00  10.1  0.16  8.41  762.0  189.0
# 139562      139563  2016-11-08 08:51:00  10.1  0.17  8.41  762.0  190.0
# 139563      139564  2016-11-08 08:52:00  10.1  0.17  8.41  762.0  190.0
# 139564      139565  2016-11-08 08:53:00  10.1  0.17  8.41  762.0  190.0
# 139565      139566  2016-11-08 08:54:00  10.1  0.17  8.41  762.0  189.0
#
#         Trueb   Cl_2      Fm   Fm_2  EVENT
# 0       0.011  0.118  1677.0  695.0  False
# ...

# %%
wq.columns
# Out:
# Index(['Unnamed: 0', 'Time', 'Tp', 'Cl', 'pH', 'Redox', 'Leit', 'Trueb',
#        'Cl_2', 'Fm', 'Fm_2', 'EVENT'],
#       dtype='object')

# %%
wq.pop('Unnamed: 0')
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 139561    139562
# 139562    139563
# 139563    139564
# 139564    139565
# 139565    139566
# Name: Unnamed: 0, Length: 139566, dtype: int64

# %%
wq
# Out:
#                        Time    Tp    Cl    pH  Redox   Leit  Trueb   Cl_2  \
# 0       2016-08-03 11:49:00   6.5  0.17  8.36  749.0  211.0  0.011  0.118
# 1       2016-08-03 11:50:00   6.5  0.17  8.36  749.0  211.0  0.011  0.118
# 2       2016-08-03 11:51:00   6.5  0.17  8.35  749.0  211.0  0.011  0.117
# 3       2016-08-03 11:52:00   6.5  0.17  8.35  749.0  211.0  0.011  0.118
# 4       2016-08-03 11:53:00   6.5  0.17  8.35  749.0  211.0  0.011  0.118
# ...                     ...   ...   ...   ...    ...    ...    ...    ...
# 139561  2016-11-08 08:50:00  10.1  0.16  8.41  762.0  189.0  0.023  0.105
# 139562  2016-11-08 08:51:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139563  2016-11-08 08:52:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139564  2016-11-08 08:53:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139565  2016-11-08 08:54:00  10.1  0.17  8.41  762.0  189.0  0.022  0.106
#
#             Fm   Fm_2  EVENT
# 0       1677.0  695.0  False
# ...

# %%
wq['Time']
# Out:
# 0         2016-08-03 11:49:00
# 1         2016-08-03 11:50:00
# 2         2016-08-03 11:51:00
# 3         2016-08-03 11:52:00
# 4         2016-08-03 11:53:00
#                  ...
# 139561    2016-11-08 08:50:00
# 139562    2016-11-08 08:51:00
# 139563    2016-11-08 08:52:00
# 139564    2016-11-08 08:53:00
# 139565    2016-11-08 08:54:00
# Name: Time, Length: 139566, dtype: object

# %%
wq['Time']=pd.to_datetime(wq['Time'], format='%Y-%m-%d %H:%M:%S')

# %%
wq
# Out:
#                       Time    Tp    Cl    pH  Redox   Leit  Trueb   Cl_2  \
# 0      2016-08-03 11:49:00   6.5  0.17  8.36  749.0  211.0  0.011  0.118
# 1      2016-08-03 11:50:00   6.5  0.17  8.36  749.0  211.0  0.011  0.118
# 2      2016-08-03 11:51:00   6.5  0.17  8.35  749.0  211.0  0.011  0.117
# 3      2016-08-03 11:52:00   6.5  0.17  8.35  749.0  211.0  0.011  0.118
# 4      2016-08-03 11:53:00   6.5  0.17  8.35  749.0  211.0  0.011  0.118
# ...                    ...   ...   ...   ...    ...    ...    ...    ...
# 139561 2016-11-08 08:50:00  10.1  0.16  8.41  762.0  189.0  0.023  0.105
# 139562 2016-11-08 08:51:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139563 2016-11-08 08:52:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139564 2016-11-08 08:53:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139565 2016-11-08 08:54:00  10.1  0.17  8.41  762.0  189.0  0.022  0.106
#
#             Fm   Fm_2  EVENT
# 0       1677.0  695.0  False
# 1       1561.0  696.0  False
# ...

# %%
wq['Time']
# Out:
# 0        2016-08-03 11:49:00
# 1        2016-08-03 11:50:00
# 2        2016-08-03 11:51:00
# 3        2016-08-03 11:52:00
# 4        2016-08-03 11:53:00
#                  ...
# 139561   2016-11-08 08:50:00
# 139562   2016-11-08 08:51:00
# 139563   2016-11-08 08:52:00
# 139564   2016-11-08 08:53:00
# 139565   2016-11-08 08:54:00
# Name: Time, Length: 139566, dtype: datetime64[ns]

# %%
wq['Date']=wq['Time'].dt.date
wq['time']=wq['Time'].dt.time

# %%
wq
# Out:
#                       Time    Tp    Cl    pH  Redox   Leit  Trueb   Cl_2  \
# 0      2016-08-03 11:49:00   6.5  0.17  8.36  749.0  211.0  0.011  0.118
# 1      2016-08-03 11:50:00   6.5  0.17  8.36  749.0  211.0  0.011  0.118
# 2      2016-08-03 11:51:00   6.5  0.17  8.35  749.0  211.0  0.011  0.117
# 3      2016-08-03 11:52:00   6.5  0.17  8.35  749.0  211.0  0.011  0.118
# 4      2016-08-03 11:53:00   6.5  0.17  8.35  749.0  211.0  0.011  0.118
# ...                    ...   ...   ...   ...    ...    ...    ...    ...
# 139561 2016-11-08 08:50:00  10.1  0.16  8.41  762.0  189.0  0.023  0.105
# 139562 2016-11-08 08:51:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139563 2016-11-08 08:52:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139564 2016-11-08 08:53:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139565 2016-11-08 08:54:00  10.1  0.17  8.41  762.0  189.0  0.022  0.106
#
#             Fm   Fm_2  EVENT        Date      time
# ...

# %%
wq.pop('Time')
# Out:
# 0        2016-08-03 11:49:00
# 1        2016-08-03 11:50:00
# 2        2016-08-03 11:51:00
# 3        2016-08-03 11:52:00
# 4        2016-08-03 11:53:00
#                  ...
# 139561   2016-11-08 08:50:00
# 139562   2016-11-08 08:51:00
# 139563   2016-11-08 08:52:00
# 139564   2016-11-08 08:53:00
# 139565   2016-11-08 08:54:00
# Name: Time, Length: 139566, dtype: datetime64[ns]

# %%
wq
# Out:
#           Tp    Cl    pH  Redox   Leit  Trueb   Cl_2      Fm   Fm_2  EVENT  \
# 0        6.5  0.17  8.36  749.0  211.0  0.011  0.118  1677.0  695.0  False
# 1        6.5  0.17  8.36  749.0  211.0  0.011  0.118  1561.0  696.0  False
# 2        6.5  0.17  8.35  749.0  211.0  0.011  0.117  1581.0  696.0  False
# 3        6.5  0.17  8.35  749.0  211.0  0.011  0.118  1579.0  693.0  False
# 4        6.5  0.17  8.35  749.0  211.0  0.011  0.118  1567.0  689.0  False
# ...      ...   ...   ...    ...    ...    ...    ...     ...    ...    ...
# 139561  10.1  0.16  8.41  762.0  189.0  0.023  0.105  1799.0  924.0  False
# 139562  10.1  0.17  8.41  762.0  190.0  0.022  0.106  1835.0  927.0  False
# 139563  10.1  0.17  8.41  762.0  190.0  0.022  0.106  1807.0  924.0  False
# 139564  10.1  0.17  8.41  762.0  190.0  0.022  0.106  1799.0  930.0  False
# 139565  10.1  0.17  8.41  762.0  189.0  0.022  0.106  1817.0  925.0  False
#
#               Date      time
# 0       2016-08-03  11:49:00
# ...

# %%
wq.dtypes
# Out:
# Tp       float64
# Cl       float64
# pH       float64
# Redox    float64
# Leit     float64
# Trueb    float64
# Cl_2     float64
# Fm       float64
# Fm_2     float64
# EVENT       bool
# Date      object
# time      object
# dtype: object

# %%
wq.isnull()
# Out:
#            Tp     Cl     pH  Redox   Leit  Trueb   Cl_2     Fm   Fm_2  EVENT  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 139561  False  False  False  False  False  False  False  False  False  False
# 139562  False  False  False  False  False  False  False  False  False  False
# 139563  False  False  False  False  False  False  False  False  False  False
# 139564  False  False  False  False  False  False  False  False  False  False
# 139565  False  False  False  False  False  False  False  False  False  False
#
#          Date   time
# 0       False  False
# ...

# %%
wq.isnull().sum()
# Out:
# Tp       1044
# Cl       1045
# pH       1044
# Redox    1044
# Leit     1044
# Trueb    1044
# Cl_2     1044
# Fm       1044
# Fm_2     1044
# EVENT       0
# Date        0
# time        0
# dtype: int64

# %%
wq.isnull().sum()
# Out:
# Tp       1044
# Cl       1045
# pH       1044
# Redox    1044
# Leit     1044
# Trueb    1044
# Cl_2     1044
# Fm       1044
# Fm_2     1044
# EVENT       0
# Date        0
# time        0
# dtype: int64

# %%
wq=wq[['Tp','Cl','pH','Redox','Leit','Trueb','Cl_2','Fm','Fm_2','EVENT','Date','time']].ffill()

# %%
wq.isna().sum()
# Out:
# Tp       0
# Cl       0
# pH       0
# Redox    0
# Leit     0
# Trueb    0
# Cl_2     0
# Fm       0
# Fm_2     0
# EVENT    0
# Date     0
# time     0
# dtype: int64

# %%
wq
# Out:
#           Tp    Cl    pH  Redox   Leit  Trueb   Cl_2      Fm   Fm_2  EVENT  \
# 0        6.5  0.17  8.36  749.0  211.0  0.011  0.118  1677.0  695.0  False
# 1        6.5  0.17  8.36  749.0  211.0  0.011  0.118  1561.0  696.0  False
# 2        6.5  0.17  8.35  749.0  211.0  0.011  0.117  1581.0  696.0  False
# 3        6.5  0.17  8.35  749.0  211.0  0.011  0.118  1579.0  693.0  False
# 4        6.5  0.17  8.35  749.0  211.0  0.011  0.118  1567.0  689.0  False
# ...      ...   ...   ...    ...    ...    ...    ...     ...    ...    ...
# 139561  10.1  0.16  8.41  762.0  189.0  0.023  0.105  1799.0  924.0  False
# 139562  10.1  0.17  8.41  762.0  190.0  0.022  0.106  1835.0  927.0  False
# 139563  10.1  0.17  8.41  762.0  190.0  0.022  0.106  1807.0  924.0  False
# 139564  10.1  0.17  8.41  762.0  190.0  0.022  0.106  1799.0  930.0  False
# 139565  10.1  0.17  8.41  762.0  189.0  0.022  0.106  1817.0  925.0  False
#
#               Date      time
# 0       2016-08-03  11:49:00
# ...

# %%
daily_Tp_values=wq.groupby(wq['Date'])['Tp'].mean()
daily_pH_values=wq.groupby(wq['Date'])['pH'].mean()
daily_Cl_values=wq.groupby(wq['Date'])['Cl'].mean()
daily_Cl_2_values=wq.groupby(wq['Date'])['Cl_2'].mean()
daily_Redox_values=wq.groupby(wq['Date'])['Redox'].mean()
daily_Leit_values=wq.groupby(wq['Date'])['Leit'].mean()
daily_Trueb_values=wq.groupby(wq['Date'])['Trueb'].mean()
daily_Fm_values=wq.groupby(wq['Date'])['Fm'].mean()
daily_Fm_2_values=wq.groupby(wq['Date'])['Fm_2'].mean()

# %%
Daily_values=pd.DataFrame({'Tp':daily_Tp_values,'pH':daily_pH_values,'Cl':daily_Cl_values,'Cl_2':daily_Cl_2_values,'Redox':daily_Redox_values,'Leit':daily_Leit_values,'Trueb':daily_Trueb_values,'Fm':daily_Fm_values,'Fm_2':daily_Fm_2_values})

# %%
dv=Daily_values

# %%
dv=dv.reset_index()

# %% [markdown]
# # Part 1: Relationships between Parameters that Affect Water Quality

# %%
wq.corr(numeric_only=True)
# Out:
#              Tp        Cl        pH     Redox      Leit     Trueb      Cl_2  \
# Tp     1.000000 -0.005454  0.193469  0.034143 -0.281839 -0.323621 -0.473274
# Cl    -0.005454  1.000000  0.175947  0.121893  0.024035  0.018667  0.162067
# pH     0.193469  0.175947  1.000000  0.650348 -0.154477 -0.067569  0.105629
# Redox  0.034143  0.121893  0.650348  1.000000 -0.178916  0.017456  0.459235
# Leit  -0.281839  0.024035 -0.154477 -0.178916  1.000000 -0.058891 -0.083797
# Trueb -0.323621  0.018667 -0.067569  0.017456 -0.058891  1.000000  0.318957
# Cl_2  -0.473274  0.162067  0.105629  0.459235 -0.083797  0.318957  1.000000
# Fm    -0.393328  0.020242 -0.085037  0.035131 -0.002171  0.388560  0.408978
# Fm_2  -0.065021  0.011264 -0.045705  0.046830 -0.035409  0.196313  0.176923
# EVENT -0.014339 -0.078803 -0.199748 -0.419818  0.040824  0.043492 -0.194216
#
#              Fm      Fm_2     EVENT
# Tp    -0.393328 -0.065021 -0.014339
# Cl     0.020242  0.011264 -0.078803
# ...

# %%
import matplotlib.pyplot as plt
dv.plot(x='Cl_2', y='Redox', kind='scatter', color='green')
plt.ylabel("Redox potential ( mV)")
plt.title("Relation Between Redox potential and Chlorine Dioxide ")
plt.xlabel("Chlorine Dioxide Concentration (mg/L) ");

# %% [markdown]
# Redox potential:reflects the water's ability to break down waste and contaminantes ; and affected mainlyby 3 factors chlorine dioxide ( since chlorine dioxide is a powerful disinfectant and oxidant for pre-oxidation and disinfection used at water treatment), pH and temperature. In general there is a positive relationship between chlorine dioxide and redox potential of water; an increase in chlorine dioxide will leads to an increase in redox potential too.

# %%
import matplotlib.pyplot as plt
dv.plot(x='Cl', y='Redox', kind='scatter', color='green')
plt.ylabel("Redox potential ( mV)")
plt.title("Relation Between Redox potential and Chlorine Dioxide ")
plt.xlabel("Chlorine Dioxide Concentration (mg/L) ");

# %%
import matplotlib.pyplot as plt
dv.plot(x='pH', y='Redox', kind='scatter', color='red')
plt.ylabel("Redox potential (mV)")
plt.title ("Relation Between Redox Potential and pH ")
plt.xlabel("pH");

# %% [markdown]
# Although the plot does not show a clear liner relationship between  redox potential and pH. but generally its repesnts a negative coorolation, where as pH getting up the redox values getting drop.

# %%
import matplotlib.pyplot as plt
dv.plot(x='Tp', y='Redox', kind='line', color='red')
plt.ylabel("Redox potential (mV)")
plt.title ("Relation Between Redox potential and Water Temperature ")
plt.xlabel("Temperature (°C)");

# %% [markdown]
# Although the plot does not show a clear relationship between redox potential and temperature. but generally its repesnts a positive realtion with flactuating trend with clear sudden drop of redox potential at 3 temperature points(around 7.8, 8.4, and 10.8 degrees. these drops correspond to a drop in the water flow rate at line 2 that leads to a drop in amount of chlorine dioxide 2. A negarive relation appered at around 9 to 10.8 degrees.

# %%
import matplotlib.pyplot as plt
dv.plot(x='Tp', y='Leit', kind='line', color='green')
plt.ylabel("Electric conductivity of the water (µS/cm)")
plt.title("Relation Between Temperature and  & Electrical Conductivity")
plt.xlabel("Tp");

# %% [markdown]
# no clear relation ship between Electrical Conductivity and Temperature. But there is a clear flactuating this may be caused by other factors like:
#
# - A change in the concentration of dissolved ions.
#
# - A chemical reaction occurring at a specific temperature threshold.
#
# - The introduction of a different water source with lower conductivity.
#
# - A sensor malfunction.

# %%
import matplotlib.pyplot as plt
dv.plot(x='Cl_2', y='Leit', kind='scatter', color='red')
# Out:
# <Axes: xlabel='Cl_2', ylabel='Leit'>

# %% [markdown]
# Turbidity: the cloudiness caused by suspended particales in water.
# As showen in the figure, chlorine dioxide at flow rate 2 parameter does not have a direct, predictable relation with the electrical conductivity of the water. Electrical conductivity likely influenced by other factors like a change in water composition, or a measurement error.

# %%
import matplotlib.pyplot as plt
dv.plot(x='Cl', y='pH', kind='scatter', color='green')
plt.ylabel("pH")
plt.title("Relation Between pH and Chlorine Dioxide Concentration")
plt.xlabel("Chlorine dioxide (mg/L) in line 1");

# %%
import matplotlib.pyplot as plt
dv.plot(x='Cl_2', y='pH', kind='scatter', color='green')
plt.ylabel("pH")
plt.title("Relation Between pH and Chlorine Dioxide")
plt.xlabel("Chlorine dioxide (mg/L) in line 2");

# %% [markdown]
# the figure shows kind of negative relationship between  chlorine dioxide concentration at line 2  and pH, as chlorine dioxide concentration increases, the pH tends to decrease. This relationship is chemically plausible. When Chlorine dioxide (ClO2) is dissolved in water, it can react to form various byproducts, some of which are acidic. For example, the formation of chlorite(ClO 2-) and other species can release protons (H+) into the solution, which lowers the pH. Same relation with respect to  chlorine dioxide concentration at line 1 (but much clearer at line 2).

# %%
import matplotlib.pyplot as plt
dv.plot(x='Fm_2', y='Cl_2', kind='scatter', color='red')
plt.ylabel("Chlorine Dioxide Concentration (line 2) (mg/L)")
plt.title ("Relation Between Chlorine Dioxide Concentration and Water Flow rate ")
plt.xlabel("Water Flow rate (line_2) (m3/h)");

# %% [markdown]
# Generally,the figure shows a positive correlation between Chlorine Dioxide concentration and water flow rate at line 2,  as the water flow rate increases, the Chlorine Dioxide concentration also tends to increase. This relationship is plausible in a water treatment or distribution system, an increase in the flow rate must be followed by an increase in the chlorine dioxide concentration to maintains a target concentration.

# %%
import matplotlib.pyplot as plt
dv.plot(x='Fm', y='Trueb', kind='scatter', color='red')
plt.ylabel("Truebidty (NTU)")
plt.title ("Relation Between Water Flowrate and Truebidty")
plt.xlabel("Water Flowrate (line 1) (m3/h)");

# %% [markdown]
# The figure shows almost a positive reationship between water flow rate at line 1 and trubdity of water, as flowrate increases, truebdity inceased too. Which means that an increase in flowrate probably increased the suspended particles and dissolved substances, thus an increase in trubdity showed up.

# %%
import matplotlib.pyplot as plt
dv[['pH' , 'Redox' , 'Cl' , 'Cl_2' , 'Leit' , 'Trueb']].plot(subplots=True, figsize=(10, 12))
plt.show_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
dv.plot(x='Fm_2', y='Trueb', kind='scatter', color='red')
plt.ylabel("Truebidty (NTU)")
plt.title ("Relation Between Water Flowrate and Truebidty")
plt.xlabel("Water Flowrate (line 2) (m3/h)");

# %% [markdown]
# The figure shows no clear or strong correlation between the water flow rate at line 2 and the turbidity of the water. The highly scattered data suggests that truebidty is independent of flow rate at line 2.
